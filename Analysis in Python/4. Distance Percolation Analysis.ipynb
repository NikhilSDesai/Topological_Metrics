# %% [markdown]
# # Clustering to define UK Systems
# A key part of out analysis is defining our units of analysis within the UK street network, our cities.
#
# To do so we will use clustering to define cities for analysis.

# %%
# load relevant packages for analysis
import contextily as ctx
import dask.dataframe as dd
import dask_geopandas as dg
import fiona
import geopandas as gpd
import igraph
import graph_tool.all as gt
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.cm import ScalarMappable
from matplotlib.collections import LineCollection
import numpy as np
import networkx as nx
import osmnx as ox
import pandas as pd
import pyogrio
import seaborn as sns
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from sklearn.preprocessing import StandardScaler
from shapely.geometry import Point
from shapely.geometry import LineString, MultiLineString
import shapely.wkt
import statsmodels.api as sm
import sys
from xml import etree

# %% [markdown]
# # A. Read in Graph and Check Nodes & Edges

# %%
# simple graph for faster tetsing
G_simple = nx.read_graph('Data/G_simple.graphml')

# %%
# load graph & check
G_percolation = nx.read_graphml('Data/G_percolation.graphml')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # load graph & check
# ----> 2 G_percolation = nx.read_graphml('Data/G_percolation.graphml')
#
# NameError: name 'nx' is not defined

# %%
print(f"Number of nodes: {G_percolation.number_of_nodes()}")
print(f"Number of edges: {G_percolation.number_of_edges()}")
# Out:
# Number of nodes: 3295455
# Number of edges: 3854671

# %%
list(G_percolation.edges(data=True))[0]
# Out:
# ('CC9BEF56-6F33-47ED-AF08-BB8A6C655A1D',
#  'D3B5B123-54B7-467E-8C60-BE2383A3624B',
#  {'length': 179.0,
#   'road_classification': 'Unknown',
#   'road_function': 'Restricted Local Access Road',
#   'form_of_way': 'Single Carriageway',
#   'primary_route': False,
#   'trunk_road': False,
#   'geometry': 'LINESTRING (187422.39 887423.74, 187436.12 887429.24, 187434.34 887455.56, 187439.76 887465.66, 187472.56 887482.08, 187552.42 887522.05)',
#   'occupation_probability': 0.00927614779300641})

# %%
list(G_percolation.nodes(data=True))[0]
# Out:
# ('CC9BEF56-6F33-47ED-AF08-BB8A6C655A1D',
#  {'pos': '(187422.39, 887423.74)',
#   'form_of_road_node': 'junction',
#   'geometry': 'POINT (187422.39 887423.74)',
#   'angle': 126.44988586701946,
#   'occupation_probability': 0.7024993659278859})

# %%
print(f"Number of nodes: {G_simple.number_of_nodes()}")
print(f"Number of edges: {G_simple.number_of_edges()}")
# Out:
# Number of nodes: 1685538
# Number of edges: 1896546

# %%
list(G_simple.edges(data=True))[0]
# Out:
# ('CC9BEF56-6F33-47ED-AF08-BB8A6C655A1D',
#  'D3B5B123-54B7-467E-8C60-BE2383A3624B',
#  {'length': 179.0,
#   'road_classification': 'Unknown',
#   'road_function': 'Restricted Local Access Road',
#   'form_of_way': 'Single Carriageway',
#   'primary_route': False,
#   'trunk_road': False,
#   'geometry': 'LINESTRING (187422.39 887423.74, 187436.12 887429.24, 187434.34 887455.56, 187439.76 887465.66, 187472.56 887482.08, 187552.42 887522.05)'})

# %%
list(G_simple.nodes(data=True))[0]
# Out:
# ('CC9BEF56-6F33-47ED-AF08-BB8A6C655A1D',
#  {'pos': '(187422.39, 887423.74)',
#   'form_of_road_node': 'junction',
#   'geometry': 'POINT (187422.39 887423.74)'})

# %% [markdown]
# # B. Conduct Clustering in the Place of Percolation
# To define the systems within the UK we will conduct a percolation process by removing edges based on their length.
#
# This gradually disconnects the network, resulting in smaller, highly connected clusters. This represents connected communities or regions. This make percolation a useful tool to define systems at different scales.
#
# In Arcaute et al. 2016, they have found that cities can be identified using a percolation process with a distance threshold of 300 meters, as this distance accurately captures the complexity and boundaries of urban systems.

# %% [markdown]
# ### 1. Clustering to Identify 'Urbanised Areas' in UK

# %%
# minimum cluster size of 600 intersections
# init a new graph for clusters
G_300m = nx.Graph()

# add edges & nodes to new graph using d=300m
for u, v, data in G_percolation.edges(data=True):
    if data['length'] <= 300:
        if not G_300m.has_node(u):
            G_300m.add_node(u, **G_percolation.nodes[u])
        if not G_300m.has_node(v):
            G_300m.add_node(v, **G_percolation.nodes[v])
        G_300m.add_edge(u, v, **data)

# save new graph
nx.write_graphml(G_300m, "Data/G_300m.graphml")

# filter clusters by size
clusters_600 = [c for c in nx.connected_components(G_300m) if len(c) > 600]
print(f"Number of clusters (cities) identified: {len(clusters_600)}")
# Out:
# Number of clusters (cities) identified: 533

# %%
# minimum cluster size of 190 intersections
# filter clusters by size
clusters_190 = [c for c in nx.connected_components(G_300m) if len(c) > 190]
print(f"Number of clusters (cities) identified: {len(clusters_190)}")
# Out:
# Number of clusters (cities) identified: 1483

# %%
G_300m = nx.read_graphml('Data/G_300m.graphml')

# %%
print(f"Number of nodes: {G_300m.number_of_nodes()}")
print(f"Number of edges: {G_300m.number_of_edges()}")
# Out:
# Number of nodes: 3161041
# Number of edges: 3448220

# %% [markdown]
# # C. Plotting Clusters at different Scales

# %% [markdown]
# ### G_percolation, d=300m, miniumum cluster size = 190 intersections

# %%
# G_percolation, d=300m, miniumum cluster size = 190 intersections
color_map = plt.cm.tab20.colors

# dictioanry for plotting 'pos'
pos = {node: tuple(map(float, data['pos'].strip('()').split(', '))) for node, data in G_300m.nodes(data=True)}

# plot
plt.figure(figsize=(20, 30))

for i, clusters_190 in enumerate(clusters_190):
    cluster_subgraph = G_300m.subgraph(clusters_190)
    node_color = color_map[i % len(color_map)]
    
    # plot nodes
    nx.draw_networkx_nodes(cluster_subgraph, pos, node_size=10, node_color=[node_color] * len(clusters_190))
    
    # plot edges using LINESTRING
    for u, v, data in cluster_subgraph.edges(data=True):
        line = LineString([tuple(map(float, coord.split())) for coord in data['geometry'].strip('LINESTRING ()').split(', ')])
        x, y = line.xy
        plt.plot(x, y, color=node_color, linewidth=1)

plt.title("Geographical Plot of Clusters Identified at 300m Threshold")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %%
# G_percolation, d=300m, miniumum cluster size = 600 intersections
color_map = plt.cm.tab20.colors

# dictioanry for plotting 'pos'
pos = {node: tuple(map(float, data['pos'].strip('()').split(', '))) for node, data in G_300m.nodes(data=True)}

# plot
plt.figure(figsize=(20, 30))

for i, clusters_600 in enumerate(clusters_600m):
    cluster_subgraph = G_300m.subgraph(clusters_600m)
    node_color = color_map[i % len(color_map)]

    # plot nodes
    nx.draw_networkx_nodes(cluster_subgraph, pos, node_size=10, node_color=[node_color] * len(clusters_600m))
    
    # plot edges using LINESTRING
    for u, v, data in cluster_subgraph.edges(data=True):
        line = LineString([tuple(map(float, coord.split())) for coord in data['geometry'].strip('LINESTRING ()').split(', ')])
        x, y = line.xy
        plt.plot(x, y, color=node_color, linewidth=1)

plt.title("Geographical Plot of Clusters Identified at 300m Threshold")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# ### G_simple, d=300m, miniumum cluster size = 600 intersections

# %%
# G_simple, d=300m, miniumum cluster size = 600 intersections
color_map = plt.cm.tab20.colors

# dictioanry for plotting 'pos'
pos = {node: tuple(map(float, data['pos'].strip('()').split(', '))) for node, data in G_300m.nodes(data=True)}

# plot
plt.figure(figsize=(12, 15))

for i, cluster in enumerate(clusters):
    cluster_subgraph = G_300m.subgraph(cluster)
    node_color = color_map[i % len(color_map)]
    
    # draw nodes
    nx.draw_networkx_nodes(cluster_subgraph, pos, node_size=10, node_color=[node_color] * len(cluster))
    
    # draw edges with LINESTRING geometries
    for u, v, data in cluster_subgraph.edges(data=True):
        line = LineString([tuple(map(float, coord.split())) for coord in data['geometry'].strip('LINESTRING ()').split(', ')])
        x, y = line.xy
        plt.plot(x, y, color=node_color, linewidth=1)

plt.title("Geographical Plot of Clusters Identified at 300m Threshold")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %% [markdown]
# # D. Choose our Systems for Analysis (2 Options)

# %% [markdown]
# In the previous section we identified *533* systems using the following metrics:
# 1. A minimum road segment length of d=300m
# 2. A miniumum cluster size = 600 intersections
#
# The next stage in our analysis intends to assess the spatial hierarchy of these clusters. This will allows us to assign a betweeness centrality score to each road segment in our network. However processing 533 different clusters is not only computationally intensive, but may not neccessarily yield a richer conclusion. In simpler terms, the conputational intensity endured will not neccessarily yield better results.
#
# Here, we ponder two potential method to reduce the number of clusters needed for analysis:
# 1. **Cluster Size**: Larger clusters are likely to represent more significant urban areas. By focusing on the size, you can ensure that the urban areas you select are substantial enough to warrant detailed analysis.
#
# 2. **Average Clustering Coefficient**: This metric measures the degree to which nodes in a graph tend to cluster together. A higher average clustering coefficient indicates a higher local density, which can help identify well-connected and coherent urban areas.

# %% [markdown]
# # E. Grouping Clusters Based on their Nature
#
# We have now clustered our data into the systems we will use for our analysis. We will now categorise these cluster into relevant scales.
#
# NetworkX as a package experiences severe difficulty processing larger graphs. Thus we use *graph_tool* a library far faster due to its optimised C++ backend. This code is written below.

# %%
import graph_tool.all as gt

# %%
# convert nx graph to graph-tool
def nx_to_gt(nx_graph):
    gt_graph = gt.Graph(directed=False)
    nx_to_gt_map = {}
    
    for node in nx_graph.nodes:
        nx_to_gt_map[node] = gt_graph.add_vertex()
    
    for edge in nx_graph.edges:
        gt_graph.add_edge(nx_to_gt_map[edge[0]], nx_to_gt_map[edge[1]])
    
    return gt_graph

# %% [markdown]
# ## E1. Filter Clusters by Size and Create Subgraphs for Each Cluster

# %%
# uncomment if starting analysis from here
G_300m = nx.read_graphml('Data/G_300m.graphml')
# minimum cluster size of 190 intersections
# filter clusters by size
clusters_190 = [c for c in nx.connected_components(G_300m) if len(c) > 190]
print(f"Number of clusters (cities) identified: {len(clusters_190)}")
# Out:
# Number of clusters (cities) identified: 1483

# %% [markdown]
# ## E2. Calculate Diameter & Metrics for Each Cluster Using graph-tool

# %%
# calc. the diameter using graph-tool
def calculate_diameter(gt_graph):
    return gt.pseudo_diameter(gt_graph)[0]

# score for each cluster
cluster_scores = []

for idx, cluster in enumerate(clusters_190):
    print(f"Processing cluster {idx+1}/{len(clusters_190)}")  # progress logging
    
    # subgraph from nodes in the cluster
    cluster_subgraph = G_300m.subgraph(cluster).copy()
    
    # to graph-tool graph
    gt_cluster_subgraph = nx_to_gt(cluster_subgraph)
    
    # diameter
    diameter = calculate_diameter(gt_cluster_subgraph)
    
    # node count
    node_count = len(cluster_subgraph)
    
    # diameter / node count calculation
    score = diameter / node_count if node_count > 0 else 0
    
    cluster_scores.append({
        'cluster': cluster,
        'diameter': diameter,
        'node_count': node_count,
        'score': score
    })
# Out:
# Processing cluster 1/1483
# Processing cluster 2/1483
# Processing cluster 3/1483
# Processing cluster 4/1483
# Processing cluster 5/1483
# Processing cluster 6/1483
# Processing cluster 7/1483
# Processing cluster 8/1483
# Processing cluster 9/1483
# Processing cluster 10/1483
# Processing cluster 11/1483
# Processing cluster 12/1483
# Processing cluster 13/1483
# Processing cluster 14/1483
# Processing cluster 15/1483
# Processing cluster 16/1483
# Processing cluster 17/1483
# Processing cluster 18/1483
# Processing cluster 19/1483
# Processing cluster 20/1483
# Processing cluster 21/1483
# Processing cluster 22/1483
# Processing cluster 23/1483
# Processing cluster 24/1483
# Processing cluster 25/1483
# Processing cluster 26/1483
# Processing cluster 27/1483
# Processing cluster 28/1483
# Processing cluster 29/1483
# Processing cluster 30/1483
# Processing cluster 31/1483
# Processing cluster 32/1483
# Processing cluster 33/1483
# Processing cluster 34/1483
# Processing cluster 35/1483
# Processing cluster 36/1483
# Processing cluster 37/1483
# Processing cluster 38/1483
# Processing cluster 39/1483
# Processing cluster 40/1483
# Processing cluster 41/1483
# Processing cluster 42/1483
# Processing cluster 43/1483
# Processing cluster 44/1483
# Processing cluster 45/1483
# Processing cluster 46/1483
# Processing cluster 47/1483
# Processing cluster 48/1483
# Processing cluster 49/1483
# Processing cluster 50/1483
# Processing cluster 51/1483
# Processing cluster 52/1483
# Processing cluster 53/1483
# Processing cluster 54/1483
# Processing cluster 55/1483
# Processing cluster 56/1483
# Processing cluster 57/1483
# Processing cluster 58/1483
# Processing cluster 59/1483
# Processing cluster 60/1483
# Processing cluster 61/1483
# Processing cluster 62/1483
# Processing cluster 63/1483
# Processing cluster 64/1483
# Processing cluster 65/1483
# Processing cluster 66/1483
# Processing cluster 67/1483
# Processing cluster 68/1483
# Processing cluster 69/1483
# Processing cluster 70/1483
# Processing cluster 71/1483
# Processing cluster 72/1483
# Processing cluster 73/1483
# Processing cluster 74/1483
# Processing cluster 75/1483
# Processing cluster 76/1483
# Processing cluster 77/1483
# Processing cluster 78/1483
# Processing cluster 79/1483
# Processing cluster 80/1483
# Processing cluster 81/1483
# Processing cluster 82/1483
# Processing cluster 83/1483
# Processing cluster 84/1483
# Processing cluster 85/1483
# Processing cluster 86/1483
# Processing cluster 87/1483
# Processing cluster 88/1483
# Processing cluster 89/1483
# Processing cluster 90/1483
# Processing cluster 91/1483
# Processing cluster 92/1483
# Processing cluster 93/1483
# Processing cluster 94/1483
# Processing cluster 95/1483
# Processing cluster 96/1483
# Processing cluster 97/1483
# Processing cluster 98/1483
# Processing cluster 99/1483
# Processing cluster 100/1483
# Processing cluster 101/1483
# Processing cluster 102/1483
# Processing cluster 103/1483
# Processing cluster 104/1483
# Processing cluster 105/1483
# Processing cluster 106/1483
# Processing cluster 107/1483
# Processing cluster 108/1483
# Processing cluster 109/1483
# Processing cluster 110/1483
# Processing cluster 111/1483
# Processing cluster 112/1483
# Processing cluster 113/1483
# Processing cluster 114/1483
# Processing cluster 115/1483
# Processing cluster 116/1483
# Processing cluster 117/1483
# Processing cluster 118/1483
# Processing cluster 119/1483
# Processing cluster 120/1483
# Processing cluster 121/1483
# Processing cluster 122/1483
# Processing cluster 123/1483
# Processing cluster 124/1483
# Processing cluster 125/1483
# Processing cluster 126/1483
# Processing cluster 127/1483
# Processing cluster 128/1483
# Processing cluster 129/1483
# Processing cluster 130/1483
# Processing cluster 131/1483
# Processing cluster 132/1483
# Processing cluster 133/1483
# Processing cluster 134/1483
# Processing cluster 135/1483
# Processing cluster 136/1483
# Processing cluster 137/1483
# Processing cluster 138/1483
# Processing cluster 139/1483
# Processing cluster 140/1483
# Processing cluster 141/1483
# Processing cluster 142/1483
# Processing cluster 143/1483
# Processing cluster 144/1483
# Processing cluster 145/1483
# Processing cluster 146/1483
# Processing cluster 147/1483
# Processing cluster 148/1483
# Processing cluster 149/1483
# Processing cluster 150/1483
# Processing cluster 151/1483
# Processing cluster 152/1483
# Processing cluster 153/1483
# Processing cluster 154/1483
# Processing cluster 155/1483
# Processing cluster 156/1483
# Processing cluster 157/1483
# Processing cluster 158/1483
# Processing cluster 159/1483
# Processing cluster 160/1483
# Processing cluster 161/1483
# Processing cluster 162/1483
# Processing cluster 163/1483
# Processing cluster 164/1483
# Processing cluster 165/1483
# Processing cluster 166/1483
# Processing cluster 167/1483
# Processing cluster 168/1483
# Processing cluster 169/1483
# Processing cluster 170/1483
# Processing cluster 171/1483
# Processing cluster 172/1483
# Processing cluster 173/1483
# Processing cluster 174/1483
# Processing cluster 175/1483
# Processing cluster 176/1483
# Processing cluster 177/1483
# Processing cluster 178/1483
# Processing cluster 179/1483
# Processing cluster 180/1483
# Processing cluster 181/1483
# Processing cluster 182/1483
# Processing cluster 183/1483
# Processing cluster 184/1483
# Processing cluster 185/1483
# Processing cluster 186/1483
# Processing cluster 187/1483
# Processing cluster 188/1483
# Processing cluster 189/1483
# Processing cluster 190/1483
# Processing cluster 191/1483
# Processing cluster 192/1483
# Processing cluster 193/1483
# Processing cluster 194/1483
# Processing cluster 195/1483
# Processing cluster 196/1483
# Processing cluster 197/1483
# Processing cluster 198/1483
# Processing cluster 199/1483
# Processing cluster 200/1483
# Processing cluster 201/1483
# Processing cluster 202/1483
# Processing cluster 203/1483
# Processing cluster 204/1483
# Processing cluster 205/1483
# Processing cluster 206/1483
# Processing cluster 207/1483
# Processing cluster 208/1483
# Processing cluster 209/1483
# Processing cluster 210/1483
# Processing cluster 211/1483
# Processing cluster 212/1483
# Processing cluster 213/1483
# Processing cluster 214/1483
# Processing cluster 215/1483
# Processing cluster 216/1483
# Processing cluster 217/1483
# Processing cluster 218/1483
# Processing cluster 219/1483
# Processing cluster 220/1483
# Processing cluster 221/1483
# Processing cluster 222/1483
# Processing cluster 223/1483
# Processing cluster 224/1483
# Processing cluster 225/1483
# Processing cluster 226/1483
# Processing cluster 227/1483
# Processing cluster 228/1483
# Processing cluster 229/1483
# Processing cluster 230/1483
# Processing cluster 231/1483
# Processing cluster 232/1483
# Processing cluster 233/1483
# Processing cluster 234/1483
# Processing cluster 235/1483
# Processing cluster 236/1483
# Processing cluster 237/1483
# Processing cluster 238/1483
# Processing cluster 239/1483
# Processing cluster 240/1483
# Processing cluster 241/1483
# Processing cluster 242/1483
# Processing cluster 243/1483
# Processing cluster 244/1483
# Processing cluster 245/1483
# Processing cluster 246/1483
# Processing cluster 247/1483
# Processing cluster 248/1483
# Processing cluster 249/1483
# Processing cluster 250/1483
# Processing cluster 251/1483
# Processing cluster 252/1483
# Processing cluster 253/1483
# Processing cluster 254/1483
# Processing cluster 255/1483
# Processing cluster 256/1483
# Processing cluster 257/1483
# Processing cluster 258/1483
# Processing cluster 259/1483
# Processing cluster 260/1483
# Processing cluster 261/1483
# Processing cluster 262/1483
# Processing cluster 263/1483
# Processing cluster 264/1483
# Processing cluster 265/1483
# Processing cluster 266/1483
# Processing cluster 267/1483
# Processing cluster 268/1483
# Processing cluster 269/1483
# Processing cluster 270/1483
# Processing cluster 271/1483
# Processing cluster 272/1483
# Processing cluster 273/1483
# Processing cluster 274/1483
# Processing cluster 275/1483
# Processing cluster 276/1483
# Processing cluster 277/1483
# Processing cluster 278/1483
# Processing cluster 279/1483
# Processing cluster 280/1483
# Processing cluster 281/1483
# Processing cluster 282/1483
# Processing cluster 283/1483
# Processing cluster 284/1483
# Processing cluster 285/1483
# Processing cluster 286/1483
# Processing cluster 287/1483
# Processing cluster 288/1483
# Processing cluster 289/1483
# Processing cluster 290/1483
# Processing cluster 291/1483
# Processing cluster 292/1483
# Processing cluster 293/1483
# Processing cluster 294/1483
# Processing cluster 295/1483
# Processing cluster 296/1483
# Processing cluster 297/1483
# Processing cluster 298/1483
# Processing cluster 299/1483
# Processing cluster 300/1483
# Processing cluster 301/1483
# Processing cluster 302/1483
# Processing cluster 303/1483
# Processing cluster 304/1483
# Processing cluster 305/1483
# Processing cluster 306/1483
# Processing cluster 307/1483
# Processing cluster 308/1483
# Processing cluster 309/1483
# Processing cluster 310/1483
# Processing cluster 311/1483
# Processing cluster 312/1483
# Processing cluster 313/1483
# Processing cluster 314/1483
# Processing cluster 315/1483
# Processing cluster 316/1483
# Processing cluster 317/1483
# Processing cluster 318/1483
# Processing cluster 319/1483
# Processing cluster 320/1483
# Processing cluster 321/1483
# Processing cluster 322/1483
# Processing cluster 323/1483
# Processing cluster 324/1483
# Processing cluster 325/1483
# Processing cluster 326/1483
# Processing cluster 327/1483
# Processing cluster 328/1483
# Processing cluster 329/1483
# Processing cluster 330/1483
# Processing cluster 331/1483
# Processing cluster 332/1483
# Processing cluster 333/1483
# Processing cluster 334/1483
# Processing cluster 335/1483
# Processing cluster 336/1483
# Processing cluster 337/1483
# Processing cluster 338/1483
# Processing cluster 339/1483
# Processing cluster 340/1483
# Processing cluster 341/1483
# Processing cluster 342/1483
# Processing cluster 343/1483
# Processing cluster 344/1483
# Processing cluster 345/1483
# Processing cluster 346/1483
# Processing cluster 347/1483
# Processing cluster 348/1483
# Processing cluster 349/1483
# Processing cluster 350/1483
# Processing cluster 351/1483
# Processing cluster 352/1483
# Processing cluster 353/1483
# Processing cluster 354/1483
# Processing cluster 355/1483
# Processing cluster 356/1483
# Processing cluster 357/1483
# Processing cluster 358/1483
# Processing cluster 359/1483
# Processing cluster 360/1483
# Processing cluster 361/1483
# Processing cluster 362/1483
# Processing cluster 363/1483
# Processing cluster 364/1483
# Processing cluster 365/1483
# Processing cluster 366/1483
# Processing cluster 367/1483
# Processing cluster 368/1483
# Processing cluster 369/1483
# Processing cluster 370/1483
# Processing cluster 371/1483
# Processing cluster 372/1483
# Processing cluster 373/1483
# Processing cluster 374/1483
# Processing cluster 375/1483
# Processing cluster 376/1483
# Processing cluster 377/1483
# Processing cluster 378/1483
# Processing cluster 379/1483
# Processing cluster 380/1483
# Processing cluster 381/1483
# Processing cluster 382/1483
# Processing cluster 383/1483
# Processing cluster 384/1483
# Processing cluster 385/1483
# Processing cluster 386/1483
# Processing cluster 387/1483
# Processing cluster 388/1483
# Processing cluster 389/1483
# Processing cluster 390/1483
# Processing cluster 391/1483
# Processing cluster 392/1483
# Processing cluster 393/1483
# Processing cluster 394/1483
# Processing cluster 395/1483
# Processing cluster 396/1483
# Processing cluster 397/1483
# Processing cluster 398/1483
# Processing cluster 399/1483
# Processing cluster 400/1483
# Processing cluster 401/1483
# Processing cluster 402/1483
# Processing cluster 403/1483
# Processing cluster 404/1483
# Processing cluster 405/1483
# Processing cluster 406/1483
# Processing cluster 407/1483
# Processing cluster 408/1483
# Processing cluster 409/1483
# Processing cluster 410/1483
# Processing cluster 411/1483
# Processing cluster 412/1483
# Processing cluster 413/1483
# Processing cluster 414/1483
# Processing cluster 415/1483
# Processing cluster 416/1483
# Processing cluster 417/1483
# Processing cluster 418/1483
# Processing cluster 419/1483
# Processing cluster 420/1483
# Processing cluster 421/1483
# Processing cluster 422/1483
# Processing cluster 423/1483
# Processing cluster 424/1483
# Processing cluster 425/1483
# Processing cluster 426/1483
# Processing cluster 427/1483
# Processing cluster 428/1483
# Processing cluster 429/1483
# Processing cluster 430/1483
# Processing cluster 431/1483
# Processing cluster 432/1483
# Processing cluster 433/1483
# Processing cluster 434/1483
# Processing cluster 435/1483
# Processing cluster 436/1483
# Processing cluster 437/1483
# Processing cluster 438/1483
# Processing cluster 439/1483
# Processing cluster 440/1483
# Processing cluster 441/1483
# Processing cluster 442/1483
# Processing cluster 443/1483
# Processing cluster 444/1483
# Processing cluster 445/1483
# Processing cluster 446/1483
# Processing cluster 447/1483
# Processing cluster 448/1483
# Processing cluster 449/1483
# Processing cluster 450/1483
# Processing cluster 451/1483
# Processing cluster 452/1483
# Processing cluster 453/1483
# Processing cluster 454/1483
# Processing cluster 455/1483
# Processing cluster 456/1483
# Processing cluster 457/1483
# Processing cluster 458/1483
# Processing cluster 459/1483
# Processing cluster 460/1483
# Processing cluster 461/1483
# Processing cluster 462/1483
# Processing cluster 463/1483
# Processing cluster 464/1483
# Processing cluster 465/1483
# Processing cluster 466/1483
# Processing cluster 467/1483
# Processing cluster 468/1483
# Processing cluster 469/1483
# Processing cluster 470/1483
# Processing cluster 471/1483
# Processing cluster 472/1483
# Processing cluster 473/1483
# Processing cluster 474/1483
# Processing cluster 475/1483
# Processing cluster 476/1483
# Processing cluster 477/1483
# Processing cluster 478/1483
# Processing cluster 479/1483
# Processing cluster 480/1483
# Processing cluster 481/1483
# Processing cluster 482/1483
# Processing cluster 483/1483
# Processing cluster 484/1483
# Processing cluster 485/1483
# Processing cluster 486/1483
# Processing cluster 487/1483
# Processing cluster 488/1483
# Processing cluster 489/1483
# Processing cluster 490/1483
# Processing cluster 491/1483
# Processing cluster 492/1483
# Processing cluster 493/1483
# Processing cluster 494/1483
# Processing cluster 495/1483
# Processing cluster 496/1483
# Processing cluster 497/1483
# Processing cluster 498/1483
# Processing cluster 499/1483
# Processing cluster 500/1483
# Processing cluster 501/1483
# Processing cluster 502/1483
# Processing cluster 503/1483
# Processing cluster 504/1483
# Processing cluster 505/1483
# Processing cluster 506/1483
# Processing cluster 507/1483
# Processing cluster 508/1483
# Processing cluster 509/1483
# Processing cluster 510/1483
# Processing cluster 511/1483
# Processing cluster 512/1483
# Processing cluster 513/1483
# Processing cluster 514/1483
# Processing cluster 515/1483
# Processing cluster 516/1483
# Processing cluster 517/1483
# Processing cluster 518/1483
# Processing cluster 519/1483
# Processing cluster 520/1483
# Processing cluster 521/1483
# Processing cluster 522/1483
# Processing cluster 523/1483
# Processing cluster 524/1483
# Processing cluster 525/1483
# Processing cluster 526/1483
# Processing cluster 527/1483
# Processing cluster 528/1483
# Processing cluster 529/1483
# Processing cluster 530/1483
# Processing cluster 531/1483
# Processing cluster 532/1483
# Processing cluster 533/1483
# Processing cluster 534/1483
# Processing cluster 535/1483
# Processing cluster 536/1483
# Processing cluster 537/1483
# Processing cluster 538/1483
# Processing cluster 539/1483
# Processing cluster 540/1483
# Processing cluster 541/1483
# Processing cluster 542/1483
# Processing cluster 543/1483
# Processing cluster 544/1483
# Processing cluster 545/1483
# Processing cluster 546/1483
# Processing cluster 547/1483
# Processing cluster 548/1483
# Processing cluster 549/1483
# Processing cluster 550/1483
# Processing cluster 551/1483
# Processing cluster 552/1483
# Processing cluster 553/1483
# Processing cluster 554/1483
# Processing cluster 555/1483
# Processing cluster 556/1483
# Processing cluster 557/1483
# Processing cluster 558/1483
# Processing cluster 559/1483
# Processing cluster 560/1483
# Processing cluster 561/1483
# Processing cluster 562/1483
# Processing cluster 563/1483
# Processing cluster 564/1483
# Processing cluster 565/1483
# Processing cluster 566/1483
# Processing cluster 567/1483
# Processing cluster 568/1483
# Processing cluster 569/1483
# Processing cluster 570/1483
# Processing cluster 571/1483
# Processing cluster 572/1483
# Processing cluster 573/1483
# Processing cluster 574/1483
# Processing cluster 575/1483
# Processing cluster 576/1483
# Processing cluster 577/1483
# Processing cluster 578/1483
# Processing cluster 579/1483
# Processing cluster 580/1483
# Processing cluster 581/1483
# Processing cluster 582/1483
# Processing cluster 583/1483
# Processing cluster 584/1483
# Processing cluster 585/1483
# Processing cluster 586/1483
# Processing cluster 587/1483
# Processing cluster 588/1483
# Processing cluster 589/1483
# Processing cluster 590/1483
# Processing cluster 591/1483
# Processing cluster 592/1483
# Processing cluster 593/1483
# Processing cluster 594/1483
# Processing cluster 595/1483
# Processing cluster 596/1483
# Processing cluster 597/1483
# Processing cluster 598/1483
# Processing cluster 599/1483
# Processing cluster 600/1483
# Processing cluster 601/1483
# Processing cluster 602/1483
# Processing cluster 603/1483
# Processing cluster 604/1483
# Processing cluster 605/1483
# Processing cluster 606/1483
# Processing cluster 607/1483
# Processing cluster 608/1483
# Processing cluster 609/1483
# Processing cluster 610/1483
# Processing cluster 611/1483
# Processing cluster 612/1483
# Processing cluster 613/1483
# Processing cluster 614/1483
# Processing cluster 615/1483
# Processing cluster 616/1483
# Processing cluster 617/1483
# Processing cluster 618/1483
# Processing cluster 619/1483
# Processing cluster 620/1483
# Processing cluster 621/1483
# Processing cluster 622/1483
# Processing cluster 623/1483
# Processing cluster 624/1483
# Processing cluster 625/1483
# Processing cluster 626/1483
# Processing cluster 627/1483
# Processing cluster 628/1483
# Processing cluster 629/1483
# Processing cluster 630/1483
# Processing cluster 631/1483
# Processing cluster 632/1483
# Processing cluster 633/1483
# Processing cluster 634/1483
# Processing cluster 635/1483
# Processing cluster 636/1483
# Processing cluster 637/1483
# Processing cluster 638/1483
# Processing cluster 639/1483
# Processing cluster 640/1483
# Processing cluster 641/1483
# Processing cluster 642/1483
# Processing cluster 643/1483
# Processing cluster 644/1483
# Processing cluster 645/1483
# Processing cluster 646/1483
# Processing cluster 647/1483
# Processing cluster 648/1483
# Processing cluster 649/1483
# Processing cluster 650/1483
# Processing cluster 651/1483
# Processing cluster 652/1483
# Processing cluster 653/1483
# Processing cluster 654/1483
# Processing cluster 655/1483
# Processing cluster 656/1483
# Processing cluster 657/1483
# Processing cluster 658/1483
# Processing cluster 659/1483
# Processing cluster 660/1483
# Processing cluster 661/1483
# Processing cluster 662/1483
# Processing cluster 663/1483
# Processing cluster 664/1483
# Processing cluster 665/1483
# Processing cluster 666/1483
# Processing cluster 667/1483
# Processing cluster 668/1483
# Processing cluster 669/1483
# Processing cluster 670/1483
# Processing cluster 671/1483
# Processing cluster 672/1483
# Processing cluster 673/1483
# Processing cluster 674/1483
# Processing cluster 675/1483
# Processing cluster 676/1483
# Processing cluster 677/1483
# Processing cluster 678/1483
# Processing cluster 679/1483
# Processing cluster 680/1483
# Processing cluster 681/1483
# Processing cluster 682/1483
# Processing cluster 683/1483
# Processing cluster 684/1483
# Processing cluster 685/1483
# Processing cluster 686/1483
# Processing cluster 687/1483
# Processing cluster 688/1483
# Processing cluster 689/1483
# Processing cluster 690/1483
# Processing cluster 691/1483
# Processing cluster 692/1483
# Processing cluster 693/1483
# Processing cluster 694/1483
# Processing cluster 695/1483
# Processing cluster 696/1483
# Processing cluster 697/1483
# Processing cluster 698/1483
# Processing cluster 699/1483
# Processing cluster 700/1483
# Processing cluster 701/1483
# Processing cluster 702/1483
# Processing cluster 703/1483
# Processing cluster 704/1483
# Processing cluster 705/1483
# Processing cluster 706/1483
# Processing cluster 707/1483
# Processing cluster 708/1483
# Processing cluster 709/1483
# Processing cluster 710/1483
# Processing cluster 711/1483
# Processing cluster 712/1483
# Processing cluster 713/1483
# Processing cluster 714/1483
# Processing cluster 715/1483
# Processing cluster 716/1483
# Processing cluster 717/1483
# Processing cluster 718/1483
# Processing cluster 719/1483
# Processing cluster 720/1483
# Processing cluster 721/1483
# Processing cluster 722/1483
# Processing cluster 723/1483
# Processing cluster 724/1483
# Processing cluster 725/1483
# Processing cluster 726/1483
# Processing cluster 727/1483
# Processing cluster 728/1483
# Processing cluster 729/1483
# Processing cluster 730/1483
# Processing cluster 731/1483
# Processing cluster 732/1483
# Processing cluster 733/1483
# Processing cluster 734/1483
# Processing cluster 735/1483
# Processing cluster 736/1483
# Processing cluster 737/1483
# Processing cluster 738/1483
# Processing cluster 739/1483
# Processing cluster 740/1483
# Processing cluster 741/1483
# Processing cluster 742/1483
# Processing cluster 743/1483
# Processing cluster 744/1483
# Processing cluster 745/1483
# Processing cluster 746/1483
# Processing cluster 747/1483
# Processing cluster 748/1483
# Processing cluster 749/1483
# Processing cluster 750/1483
# Processing cluster 751/1483
# Processing cluster 752/1483
# Processing cluster 753/1483
# Processing cluster 754/1483
# Processing cluster 755/1483
# Processing cluster 756/1483
# Processing cluster 757/1483
# Processing cluster 758/1483
# Processing cluster 759/1483
# Processing cluster 760/1483
# Processing cluster 761/1483
# Processing cluster 762/1483
# Processing cluster 763/1483
# Processing cluster 764/1483
# Processing cluster 765/1483
# Processing cluster 766/1483
# Processing cluster 767/1483
# Processing cluster 768/1483
# Processing cluster 769/1483
# Processing cluster 770/1483
# Processing cluster 771/1483
# Processing cluster 772/1483
# Processing cluster 773/1483
# Processing cluster 774/1483
# Processing cluster 775/1483
# Processing cluster 776/1483
# Processing cluster 777/1483
# Processing cluster 778/1483
# Processing cluster 779/1483
# Processing cluster 780/1483
# Processing cluster 781/1483
# Processing cluster 782/1483
# Processing cluster 783/1483
# Processing cluster 784/1483
# Processing cluster 785/1483
# Processing cluster 786/1483
# Processing cluster 787/1483
# Processing cluster 788/1483
# Processing cluster 789/1483
# Processing cluster 790/1483
# Processing cluster 791/1483
# Processing cluster 792/1483
# Processing cluster 793/1483
# Processing cluster 794/1483
# Processing cluster 795/1483
# Processing cluster 796/1483
# Processing cluster 797/1483
# Processing cluster 798/1483
# Processing cluster 799/1483
# Processing cluster 800/1483
# Processing cluster 801/1483
# Processing cluster 802/1483
# Processing cluster 803/1483
# Processing cluster 804/1483
# Processing cluster 805/1483
# Processing cluster 806/1483
# Processing cluster 807/1483
# Processing cluster 808/1483
# Processing cluster 809/1483
# Processing cluster 810/1483
# Processing cluster 811/1483
# Processing cluster 812/1483
# Processing cluster 813/1483
# Processing cluster 814/1483
# Processing cluster 815/1483
# Processing cluster 816/1483
# Processing cluster 817/1483
# Processing cluster 818/1483
# Processing cluster 819/1483
# Processing cluster 820/1483
# Processing cluster 821/1483
# Processing cluster 822/1483
# Processing cluster 823/1483
# Processing cluster 824/1483
# Processing cluster 825/1483
# Processing cluster 826/1483
# Processing cluster 827/1483
# Processing cluster 828/1483
# Processing cluster 829/1483
# Processing cluster 830/1483
# Processing cluster 831/1483
# Processing cluster 832/1483
# Processing cluster 833/1483
# Processing cluster 834/1483
# Processing cluster 835/1483
# Processing cluster 836/1483
# Processing cluster 837/1483
# Processing cluster 838/1483
# Processing cluster 839/1483
# Processing cluster 840/1483
# Processing cluster 841/1483
# Processing cluster 842/1483
# Processing cluster 843/1483
# Processing cluster 844/1483
# Processing cluster 845/1483
# Processing cluster 846/1483
# Processing cluster 847/1483
# Processing cluster 848/1483
# Processing cluster 849/1483
# Processing cluster 850/1483
# Processing cluster 851/1483
# Processing cluster 852/1483
# Processing cluster 853/1483
# Processing cluster 854/1483
# Processing cluster 855/1483
# Processing cluster 856/1483
# Processing cluster 857/1483
# Processing cluster 858/1483
# Processing cluster 859/1483
# Processing cluster 860/1483
# Processing cluster 861/1483
# Processing cluster 862/1483
# Processing cluster 863/1483
# Processing cluster 864/1483
# Processing cluster 865/1483
# Processing cluster 866/1483
# Processing cluster 867/1483
# Processing cluster 868/1483
# Processing cluster 869/1483
# Processing cluster 870/1483
# Processing cluster 871/1483
# Processing cluster 872/1483
# Processing cluster 873/1483
# Processing cluster 874/1483
# Processing cluster 875/1483
# Processing cluster 876/1483
# Processing cluster 877/1483
# Processing cluster 878/1483
# Processing cluster 879/1483
# Processing cluster 880/1483
# Processing cluster 881/1483
# Processing cluster 882/1483
# Processing cluster 883/1483
# Processing cluster 884/1483
# Processing cluster 885/1483
# Processing cluster 886/1483
# Processing cluster 887/1483
# Processing cluster 888/1483
# Processing cluster 889/1483
# Processing cluster 890/1483
# Processing cluster 891/1483
# Processing cluster 892/1483
# Processing cluster 893/1483
# Processing cluster 894/1483
# Processing cluster 895/1483
# Processing cluster 896/1483
# Processing cluster 897/1483
# Processing cluster 898/1483
# Processing cluster 899/1483
# Processing cluster 900/1483
# Processing cluster 901/1483
# Processing cluster 902/1483
# Processing cluster 903/1483
# Processing cluster 904/1483
# Processing cluster 905/1483
# Processing cluster 906/1483
# Processing cluster 907/1483
# Processing cluster 908/1483
# Processing cluster 909/1483
# Processing cluster 910/1483
# Processing cluster 911/1483
# Processing cluster 912/1483
# Processing cluster 913/1483
# Processing cluster 914/1483
# Processing cluster 915/1483
# Processing cluster 916/1483
# Processing cluster 917/1483
# Processing cluster 918/1483
# Processing cluster 919/1483
# Processing cluster 920/1483
# Processing cluster 921/1483
# Processing cluster 922/1483
# Processing cluster 923/1483
# Processing cluster 924/1483
# Processing cluster 925/1483
# Processing cluster 926/1483
# Processing cluster 927/1483
# Processing cluster 928/1483
# Processing cluster 929/1483
# Processing cluster 930/1483
# Processing cluster 931/1483
# Processing cluster 932/1483
# Processing cluster 933/1483
# Processing cluster 934/1483
# Processing cluster 935/1483
# Processing cluster 936/1483
# Processing cluster 937/1483
# Processing cluster 938/1483
# Processing cluster 939/1483
# Processing cluster 940/1483
# Processing cluster 941/1483
# Processing cluster 942/1483
# Processing cluster 943/1483
# Processing cluster 944/1483
# Processing cluster 945/1483
# Processing cluster 946/1483
# Processing cluster 947/1483
# Processing cluster 948/1483
# Processing cluster 949/1483
# Processing cluster 950/1483
# Processing cluster 951/1483
# Processing cluster 952/1483
# Processing cluster 953/1483
# Processing cluster 954/1483
# Processing cluster 955/1483
# Processing cluster 956/1483
# Processing cluster 957/1483
# Processing cluster 958/1483
# Processing cluster 959/1483
# Processing cluster 960/1483
# Processing cluster 961/1483
# Processing cluster 962/1483
# Processing cluster 963/1483
# Processing cluster 964/1483
# Processing cluster 965/1483
# Processing cluster 966/1483
# Processing cluster 967/1483
# Processing cluster 968/1483
# Processing cluster 969/1483
# Processing cluster 970/1483
# Processing cluster 971/1483
# Processing cluster 972/1483
# Processing cluster 973/1483
# Processing cluster 974/1483
# Processing cluster 975/1483
# Processing cluster 976/1483
# Processing cluster 977/1483
# Processing cluster 978/1483
# Processing cluster 979/1483
# Processing cluster 980/1483
# Processing cluster 981/1483
# Processing cluster 982/1483
# Processing cluster 983/1483
# Processing cluster 984/1483
# Processing cluster 985/1483
# Processing cluster 986/1483
# Processing cluster 987/1483
# Processing cluster 988/1483
# Processing cluster 989/1483
# Processing cluster 990/1483
# Processing cluster 991/1483
# Processing cluster 992/1483
# Processing cluster 993/1483
# Processing cluster 994/1483
# Processing cluster 995/1483
# Processing cluster 996/1483
# Processing cluster 997/1483
# Processing cluster 998/1483
# Processing cluster 999/1483
# Processing cluster 1000/1483
# Processing cluster 1001/1483
# Processing cluster 1002/1483
# Processing cluster 1003/1483
# Processing cluster 1004/1483
# Processing cluster 1005/1483
# Processing cluster 1006/1483
# Processing cluster 1007/1483
# Processing cluster 1008/1483
# Processing cluster 1009/1483
# Processing cluster 1010/1483
# Processing cluster 1011/1483
# Processing cluster 1012/1483
# Processing cluster 1013/1483
# Processing cluster 1014/1483
# Processing cluster 1015/1483
# Processing cluster 1016/1483
# Processing cluster 1017/1483
# Processing cluster 1018/1483
# Processing cluster 1019/1483
# Processing cluster 1020/1483
# Processing cluster 1021/1483
# Processing cluster 1022/1483
# Processing cluster 1023/1483
# Processing cluster 1024/1483
# Processing cluster 1025/1483
# Processing cluster 1026/1483
# Processing cluster 1027/1483
# Processing cluster 1028/1483
# Processing cluster 1029/1483
# Processing cluster 1030/1483
# Processing cluster 1031/1483
# Processing cluster 1032/1483
# Processing cluster 1033/1483
# Processing cluster 1034/1483
# Processing cluster 1035/1483
# Processing cluster 1036/1483
# Processing cluster 1037/1483
# Processing cluster 1038/1483
# Processing cluster 1039/1483
# Processing cluster 1040/1483
# Processing cluster 1041/1483
# Processing cluster 1042/1483
# Processing cluster 1043/1483
# Processing cluster 1044/1483
# Processing cluster 1045/1483
# Processing cluster 1046/1483
# Processing cluster 1047/1483
# Processing cluster 1048/1483
# Processing cluster 1049/1483
# Processing cluster 1050/1483
# Processing cluster 1051/1483
# Processing cluster 1052/1483
# Processing cluster 1053/1483
# Processing cluster 1054/1483
# Processing cluster 1055/1483
# Processing cluster 1056/1483
# Processing cluster 1057/1483
# Processing cluster 1058/1483
# Processing cluster 1059/1483
# Processing cluster 1060/1483
# Processing cluster 1061/1483
# Processing cluster 1062/1483
# Processing cluster 1063/1483
# Processing cluster 1064/1483
# Processing cluster 1065/1483
# Processing cluster 1066/1483
# Processing cluster 1067/1483
# Processing cluster 1068/1483
# Processing cluster 1069/1483
# Processing cluster 1070/1483
# Processing cluster 1071/1483
# Processing cluster 1072/1483
# Processing cluster 1073/1483
# Processing cluster 1074/1483
# Processing cluster 1075/1483
# Processing cluster 1076/1483
# Processing cluster 1077/1483
# Processing cluster 1078/1483
# Processing cluster 1079/1483
# Processing cluster 1080/1483
# Processing cluster 1081/1483
# Processing cluster 1082/1483
# Processing cluster 1083/1483
# Processing cluster 1084/1483
# Processing cluster 1085/1483
# Processing cluster 1086/1483
# Processing cluster 1087/1483
# Processing cluster 1088/1483
# Processing cluster 1089/1483
# Processing cluster 1090/1483
# Processing cluster 1091/1483
# Processing cluster 1092/1483
# Processing cluster 1093/1483
# Processing cluster 1094/1483
# Processing cluster 1095/1483
# Processing cluster 1096/1483
# Processing cluster 1097/1483
# Processing cluster 1098/1483
# Processing cluster 1099/1483
# Processing cluster 1100/1483
# Processing cluster 1101/1483
# Processing cluster 1102/1483
# Processing cluster 1103/1483
# Processing cluster 1104/1483
# Processing cluster 1105/1483
# Processing cluster 1106/1483
# Processing cluster 1107/1483
# Processing cluster 1108/1483
# Processing cluster 1109/1483
# Processing cluster 1110/1483
# Processing cluster 1111/1483
# Processing cluster 1112/1483
# Processing cluster 1113/1483
# Processing cluster 1114/1483
# Processing cluster 1115/1483
# Processing cluster 1116/1483
# Processing cluster 1117/1483
# Processing cluster 1118/1483
# Processing cluster 1119/1483
# Processing cluster 1120/1483
# Processing cluster 1121/1483
# Processing cluster 1122/1483
# Processing cluster 1123/1483
# Processing cluster 1124/1483
# Processing cluster 1125/1483
# Processing cluster 1126/1483
# Processing cluster 1127/1483
# Processing cluster 1128/1483
# Processing cluster 1129/1483
# Processing cluster 1130/1483
# Processing cluster 1131/1483
# Processing cluster 1132/1483
# Processing cluster 1133/1483
# Processing cluster 1134/1483
# Processing cluster 1135/1483
# Processing cluster 1136/1483
# Processing cluster 1137/1483
# Processing cluster 1138/1483
# Processing cluster 1139/1483
# Processing cluster 1140/1483
# Processing cluster 1141/1483
# Processing cluster 1142/1483
# Processing cluster 1143/1483
# Processing cluster 1144/1483
# Processing cluster 1145/1483
# Processing cluster 1146/1483
# Processing cluster 1147/1483
# Processing cluster 1148/1483
# Processing cluster 1149/1483
# Processing cluster 1150/1483
# Processing cluster 1151/1483
# Processing cluster 1152/1483
# Processing cluster 1153/1483
# Processing cluster 1154/1483
# Processing cluster 1155/1483
# Processing cluster 1156/1483
# Processing cluster 1157/1483
# Processing cluster 1158/1483
# Processing cluster 1159/1483
# Processing cluster 1160/1483
# Processing cluster 1161/1483
# Processing cluster 1162/1483
# Processing cluster 1163/1483
# Processing cluster 1164/1483
# Processing cluster 1165/1483
# Processing cluster 1166/1483
# Processing cluster 1167/1483
# Processing cluster 1168/1483
# Processing cluster 1169/1483
# Processing cluster 1170/1483
# Processing cluster 1171/1483
# Processing cluster 1172/1483
# Processing cluster 1173/1483
# Processing cluster 1174/1483
# Processing cluster 1175/1483
# Processing cluster 1176/1483
# Processing cluster 1177/1483
# Processing cluster 1178/1483
# Processing cluster 1179/1483
# Processing cluster 1180/1483
# Processing cluster 1181/1483
# Processing cluster 1182/1483
# Processing cluster 1183/1483
# Processing cluster 1184/1483
# Processing cluster 1185/1483
# Processing cluster 1186/1483
# Processing cluster 1187/1483
# Processing cluster 1188/1483
# Processing cluster 1189/1483
# Processing cluster 1190/1483
# Processing cluster 1191/1483
# Processing cluster 1192/1483
# Processing cluster 1193/1483
# Processing cluster 1194/1483
# Processing cluster 1195/1483
# Processing cluster 1196/1483
# Processing cluster 1197/1483
# Processing cluster 1198/1483
# Processing cluster 1199/1483
# Processing cluster 1200/1483
# Processing cluster 1201/1483
# Processing cluster 1202/1483
# Processing cluster 1203/1483
# Processing cluster 1204/1483
# Processing cluster 1205/1483
# Processing cluster 1206/1483
# Processing cluster 1207/1483
# Processing cluster 1208/1483
# Processing cluster 1209/1483
# Processing cluster 1210/1483
# Processing cluster 1211/1483
# Processing cluster 1212/1483
# Processing cluster 1213/1483
# Processing cluster 1214/1483
# Processing cluster 1215/1483
# Processing cluster 1216/1483
# Processing cluster 1217/1483
# Processing cluster 1218/1483
# Processing cluster 1219/1483
# Processing cluster 1220/1483
# Processing cluster 1221/1483
# Processing cluster 1222/1483
# Processing cluster 1223/1483
# Processing cluster 1224/1483
# Processing cluster 1225/1483
# Processing cluster 1226/1483
# Processing cluster 1227/1483
# Processing cluster 1228/1483
# Processing cluster 1229/1483
# Processing cluster 1230/1483
# Processing cluster 1231/1483
# Processing cluster 1232/1483
# Processing cluster 1233/1483
# Processing cluster 1234/1483
# Processing cluster 1235/1483
# Processing cluster 1236/1483
# Processing cluster 1237/1483
# Processing cluster 1238/1483
# Processing cluster 1239/1483
# Processing cluster 1240/1483
# Processing cluster 1241/1483
# Processing cluster 1242/1483
# Processing cluster 1243/1483
# Processing cluster 1244/1483
# Processing cluster 1245/1483
# Processing cluster 1246/1483
# Processing cluster 1247/1483
# Processing cluster 1248/1483
# Processing cluster 1249/1483
# Processing cluster 1250/1483
# Processing cluster 1251/1483
# Processing cluster 1252/1483
# Processing cluster 1253/1483
# Processing cluster 1254/1483
# Processing cluster 1255/1483
# Processing cluster 1256/1483
# Processing cluster 1257/1483
# Processing cluster 1258/1483
# Processing cluster 1259/1483
# Processing cluster 1260/1483
# Processing cluster 1261/1483
# Processing cluster 1262/1483
# Processing cluster 1263/1483
# Processing cluster 1264/1483
# Processing cluster 1265/1483
# Processing cluster 1266/1483
# Processing cluster 1267/1483
# Processing cluster 1268/1483
# Processing cluster 1269/1483
# Processing cluster 1270/1483
# Processing cluster 1271/1483
# Processing cluster 1272/1483
# Processing cluster 1273/1483
# Processing cluster 1274/1483
# Processing cluster 1275/1483
# Processing cluster 1276/1483
# Processing cluster 1277/1483
# Processing cluster 1278/1483
# Processing cluster 1279/1483
# Processing cluster 1280/1483
# Processing cluster 1281/1483
# Processing cluster 1282/1483
# Processing cluster 1283/1483
# Processing cluster 1284/1483
# Processing cluster 1285/1483
# Processing cluster 1286/1483
# Processing cluster 1287/1483
# Processing cluster 1288/1483
# Processing cluster 1289/1483
# Processing cluster 1290/1483
# Processing cluster 1291/1483
# Processing cluster 1292/1483
# Processing cluster 1293/1483
# Processing cluster 1294/1483
# Processing cluster 1295/1483
# Processing cluster 1296/1483
# Processing cluster 1297/1483
# Processing cluster 1298/1483
# Processing cluster 1299/1483
# Processing cluster 1300/1483
# Processing cluster 1301/1483
# Processing cluster 1302/1483
# Processing cluster 1303/1483
# Processing cluster 1304/1483
# Processing cluster 1305/1483
# Processing cluster 1306/1483
# Processing cluster 1307/1483
# Processing cluster 1308/1483
# Processing cluster 1309/1483
# Processing cluster 1310/1483
# Processing cluster 1311/1483
# Processing cluster 1312/1483
# Processing cluster 1313/1483
# Processing cluster 1314/1483
# Processing cluster 1315/1483
# Processing cluster 1316/1483
# Processing cluster 1317/1483
# Processing cluster 1318/1483
# Processing cluster 1319/1483
# Processing cluster 1320/1483
# Processing cluster 1321/1483
# Processing cluster 1322/1483
# Processing cluster 1323/1483
# Processing cluster 1324/1483
# Processing cluster 1325/1483
# Processing cluster 1326/1483
# Processing cluster 1327/1483
# Processing cluster 1328/1483
# Processing cluster 1329/1483
# Processing cluster 1330/1483
# Processing cluster 1331/1483
# Processing cluster 1332/1483
# Processing cluster 1333/1483
# Processing cluster 1334/1483
# Processing cluster 1335/1483
# Processing cluster 1336/1483
# Processing cluster 1337/1483
# Processing cluster 1338/1483
# Processing cluster 1339/1483
# Processing cluster 1340/1483
# Processing cluster 1341/1483
# Processing cluster 1342/1483
# Processing cluster 1343/1483
# Processing cluster 1344/1483
# Processing cluster 1345/1483
# Processing cluster 1346/1483
# Processing cluster 1347/1483
# Processing cluster 1348/1483
# Processing cluster 1349/1483
# Processing cluster 1350/1483
# Processing cluster 1351/1483
# Processing cluster 1352/1483
# Processing cluster 1353/1483
# Processing cluster 1354/1483
# Processing cluster 1355/1483
# Processing cluster 1356/1483
# Processing cluster 1357/1483
# Processing cluster 1358/1483
# Processing cluster 1359/1483
# Processing cluster 1360/1483
# Processing cluster 1361/1483
# Processing cluster 1362/1483
# Processing cluster 1363/1483
# Processing cluster 1364/1483
# Processing cluster 1365/1483
# Processing cluster 1366/1483
# Processing cluster 1367/1483
# Processing cluster 1368/1483
# Processing cluster 1369/1483
# Processing cluster 1370/1483
# Processing cluster 1371/1483
# Processing cluster 1372/1483
# Processing cluster 1373/1483
# Processing cluster 1374/1483
# Processing cluster 1375/1483
# Processing cluster 1376/1483
# Processing cluster 1377/1483
# Processing cluster 1378/1483
# Processing cluster 1379/1483
# Processing cluster 1380/1483
# Processing cluster 1381/1483
# Processing cluster 1382/1483
# Processing cluster 1383/1483
# Processing cluster 1384/1483
# Processing cluster 1385/1483
# Processing cluster 1386/1483
# Processing cluster 1387/1483
# Processing cluster 1388/1483
# Processing cluster 1389/1483
# Processing cluster 1390/1483
# Processing cluster 1391/1483
# Processing cluster 1392/1483
# Processing cluster 1393/1483
# Processing cluster 1394/1483
# Processing cluster 1395/1483
# Processing cluster 1396/1483
# Processing cluster 1397/1483
# Processing cluster 1398/1483
# Processing cluster 1399/1483
# Processing cluster 1400/1483
# Processing cluster 1401/1483
# Processing cluster 1402/1483
# Processing cluster 1403/1483
# Processing cluster 1404/1483
# Processing cluster 1405/1483
# Processing cluster 1406/1483
# Processing cluster 1407/1483
# Processing cluster 1408/1483
# Processing cluster 1409/1483
# Processing cluster 1410/1483
# Processing cluster 1411/1483
# Processing cluster 1412/1483
# Processing cluster 1413/1483
# Processing cluster 1414/1483
# Processing cluster 1415/1483
# Processing cluster 1416/1483
# Processing cluster 1417/1483
# Processing cluster 1418/1483
# Processing cluster 1419/1483
# Processing cluster 1420/1483
# Processing cluster 1421/1483
# Processing cluster 1422/1483
# Processing cluster 1423/1483
# Processing cluster 1424/1483
# Processing cluster 1425/1483
# Processing cluster 1426/1483
# Processing cluster 1427/1483
# Processing cluster 1428/1483
# Processing cluster 1429/1483
# Processing cluster 1430/1483
# Processing cluster 1431/1483
# Processing cluster 1432/1483
# Processing cluster 1433/1483
# Processing cluster 1434/1483
# Processing cluster 1435/1483
# Processing cluster 1436/1483
# Processing cluster 1437/1483
# Processing cluster 1438/1483
# Processing cluster 1439/1483
# Processing cluster 1440/1483
# Processing cluster 1441/1483
# Processing cluster 1442/1483
# Processing cluster 1443/1483
# Processing cluster 1444/1483
# Processing cluster 1445/1483
# Processing cluster 1446/1483
# Processing cluster 1447/1483
# Processing cluster 1448/1483
# Processing cluster 1449/1483
# Processing cluster 1450/1483
# Processing cluster 1451/1483
# Processing cluster 1452/1483
# Processing cluster 1453/1483
# Processing cluster 1454/1483
# Processing cluster 1455/1483
# Processing cluster 1456/1483
# Processing cluster 1457/1483
# Processing cluster 1458/1483
# Processing cluster 1459/1483
# Processing cluster 1460/1483
# Processing cluster 1461/1483
# Processing cluster 1462/1483
# Processing cluster 1463/1483
# Processing cluster 1464/1483
# Processing cluster 1465/1483
# Processing cluster 1466/1483
# Processing cluster 1467/1483
# Processing cluster 1468/1483
# Processing cluster 1469/1483
# Processing cluster 1470/1483
# Processing cluster 1471/1483
# Processing cluster 1472/1483
# Processing cluster 1473/1483
# Processing cluster 1474/1483
# Processing cluster 1475/1483
# Processing cluster 1476/1483
# Processing cluster 1477/1483
# Processing cluster 1478/1483
# Processing cluster 1479/1483
# Processing cluster 1480/1483
# Processing cluster 1481/1483
# Processing cluster 1482/1483
# Processing cluster 1483/1483

# %%
# sorted clusters x score (diameter/node count)
sorted_clusters = sorted(cluster_scores, key=lambda x: x['score'], reverse=True)
print('Clusters Sorted based on Diameter / Node Count')

# convert to df and ensure calculations are correct
sorted_clusters_df = pd.DataFrame(sorted_clusters)
# Out:
# Clusters Sorted based on Diameter / Node Count

# %%
#.head() to inspect df
sorted_clusters_df.head()
# Out:
#                                              cluster  diameter  node_count  \
# 0  {10A6ECD9-E25C-4786-9FAC-C72614ECB287, B1995FD...      62.0         196
# 1  {5E7C74F0-D0EF-4A8A-AF90-EE18D18C8423, 762DECF...      73.0         246
# 2  {66E39740-ECC1-4D8A-801A-024400C02EF9, B61B1DD...      61.0         216
# 3  {8DD9B8DD-688F-4AF8-AAFD-0C183C328016, 8F2C7A9...      58.0         208
# 4  {04E51D5C-AF45-45A3-8A7A-88C51F056B22, 30C36F4...      58.0         211
#
#       score
# 0  0.316327
# 1  0.296748
# 2  0.282407
# 3  0.278846
# 4  0.274882

# %%
# .info() to inspect df
sorted_clusters_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1483 entries, 0 to 1482
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   cluster     1483 non-null   object
#  1   diameter    1483 non-null   float64
#  2   node_count  1483 non-null   int64
#  3   score       1483 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 46.5+ KB

# %%
# save sorted clusters df as a csv
# sorted_clusters_df.to_csv('Data/sorted_clusters.csv', index=False)

# %%
import os
os.getcwd()
# Out:
# '/Users/nikhildesai/Documents/UCLT2/Dissertation/Multiscale_Centrality'

# %%
sorted_clusters_df = pd.read_csv('Data/sorted_clusters.csv')

# %%
# round to 2 decimals
sorted_clusters_df['score'] = sorted_clusters_df['score'].round(2)

# descriptive stats
descriptive_stats = sorted_clusters_df.describe()
print(descriptive_stats)
# Out:
#           diameter     node_count        score
# count  1483.000000    1483.000000  1483.000000
# mean     74.117330    1373.412677     0.122097
# std      71.152663    6927.477032     0.050454
# min      24.000000     191.000000     0.010000
# 25%      42.000000     266.000000     0.090000
# 50%      54.000000     429.000000     0.120000
# 75%      79.000000     853.500000     0.160000
# max    1311.000000  188635.000000     0.320000

# %% [markdown]
# ## E3. Plots of Unstandardised DF

# %% [markdown]
# #### Diameter:
# Count: 1483 urban systems.
# Mean: The average diameter is 74.11. This suggests that, on average, the longest shortest path within these urban systems is about 74 units (this could be in terms of intersections or other relevant units).
# Standard Deviation (std): 71.15. There is significant variability in the diameter of these urban systems.
# Minimum (min): The smallest diameter is 23.
# 25th Percentile (25%): 25% of the urban systems have a diameter less than or equal to 42.
# Median (50%): The median diameter is 54, indicating that half of the urban systems have a diameter less than or equal to 54 and the other half have a diameter greater than 54.
# 75th Percentile (75%): 75% of the urban systems have a diameter less than or equal to 79.
# Maximum (max): The largest diameter is 1311, showing the presence of some very large urban systems.
#
# #### Node Count:
# Count: 1483 urban systems.
# Mean: The average node count is 1373.41. On average, there are about 1373 intersections or nodes in these urban systems.
# Standard Deviation (std): 6927.48. There is extremely high variability in the number of nodes, indicating the presence of both very small and very large urban systems.
# Minimum (min): The smallest urban system has 191 nodes.
# 25th Percentile (25%): 25% of the urban systems have 266 nodes or fewer.
# Median (50%): The median node count is 429, indicating that half of the urban systems have 429 nodes or fewer.
# 75th Percentile (75%): 75% of the urban systems have 853.5 nodes or fewer.
# Maximum (max): The largest urban system has 188,635 nodes, indicating the presence of some very large and complex urban systems.
#
# #### Score (Diameter/Node Count):
# Count: 1483 urban systems.
# Mean: The average score is 0.12209. This score represents the average ratio of the diameter to the node count, giving a sense of the efficiency or spread of the urban systems.
# Standard Deviation (std): 0.05047. There is moderate variability in the scores.
# Minimum (min): The smallest score is 0.01, indicating very efficient or compact urban systems.
# 25th Percentile (25%): 25% of the urban systems have a score of 0.085 or lower.
# Median (50%): The median score is 0.12, indicating that half of the urban systems have a score of 0.12 or lower.
# 75th Percentile (75%): 75% of the urban systems have a score of 0.16 or lower.
# Maximum (max): The highest score is 0.32, indicating some urban systems are less efficient or more spread out.
#
# #### Interpretation:
# Diameter: The data shows a wide range of diameters, with most urban systems having diameters between 23 and 1311. The high standard deviation suggests that while many urban systems have moderate diameters, some are exceptionally large.
#
# Node Count: There is a considerable range in the number of nodes across urban systems, from very small systems with just 191 nodes to very large systems with up to 188,635 nodes. The large standard deviation indicates that most urban systems have a moderate number of nodes, but a few systems are extremely large.
#
# Score: The scores provide an indication of the relative compactness or spread of the urban systems. The scores range from 0.01 to 0.32, with most systems falling between 0.085 and 0.16. A higher score suggests a more spread-out urban system relative to its size, while a lower score indicates a more compact system.
#
# #### Categorization:
# Based on the score, urban systems can be categorized into different types:
#
# Compact Systems: Scores closer to the minimum (0.01).
# Moderately Compact Systems: Scores around the median (0.12).
# Spread-Out Systems: Scores closer to the maximum (0.32).
# These categories can help in understanding the nature of different urban systems and planning accordingly.

# %%
# histogram of scores
plt.figure(figsize=(10, 6))
plt.hist(sorted_clusters_df['score'], bins=20, edgecolor='black')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.title('Histogram of Cluster Scores')
plt.grid(True)
plt.show()

# %%
# histogram of scores
plt.figure(figsize=(10, 6))
plt.hist(sorted_clusters_df['score'], bins=20, edgecolor='black')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.title('Histogram of Cluster Scores')
plt.grid(True)
plt.show()

# scatter of diameter vs. score
plt.figure(figsize=(10, 6))
plt.scatter(sorted_clusters_df['diameter'], sorted_clusters_df['score'], alpha=0.5)
plt.xlabel('Diameter')
plt.ylabel('Score')
plt.title('Scatter Plot of Diameter vs. Score')
plt.grid(True)
plt.show()

# histogram of diameters
plt.figure(figsize=(10, 6))
plt.hist(sorted_clusters_df['diameter'], bins=20, edgecolor='black')
plt.xlabel('Diameter')
plt.ylabel('Frequency')
plt.title('Histogram of Cluster Diameters')
plt.grid(True)
plt.show()

# scatter of diameter vs. node_count
plt.figure(figsize=(10, 6))
plt.scatter(sorted_clusters_df['diameter'], sorted_clusters_df['node_count'], alpha=0.5)
plt.xlabel('Diameter')
plt.ylabel('Node Count')
plt.title('Scatter Plot of Diameter vs. Node Count')
plt.grid(True)
plt.show()

# histogram of node counts
plt.figure(figsize=(10, 6))
plt.hist(sorted_clusters_df['node_count'], bins=20, edgecolor='black')
plt.xlabel('Node Count')
plt.ylabel('Frequency')
plt.title('Histogram of Cluster Node Counts')
plt.grid(True)
plt.show()

# scatter: node_count vs. score
plt.figure(figsize=(10, 6))
plt.scatter(sorted_clusters_df['node_count'], sorted_clusters_df['score'], alpha=0.5)
plt.xlabel('Node Count')
plt.ylabel('Score')
plt.title('Scatter Plot of Node Count vs. Score')
plt.grid(True)
plt.show()
# Out:
#           diameter     node_count       score
# count  1483.000000    1483.000000  1483.00000
# mean     74.113958    1373.412677     0.12209
# std      71.153840    6927.477032     0.05047
# min      23.000000     191.000000     0.01000
# 25%      42.000000     266.000000     0.08500
# 50%      54.000000     429.000000     0.12000
# 75%      79.000000     853.500000     0.16000
# max    1311.000000  188635.000000     0.32000

# %% [markdown]
# ### Identifying London:
# London, being a major city, is expected to have:
#
# - A high node count due to its large size and complexity.
# - A large diameter because of its extensive urban spread.
# - A relatively lower score (diameter/node count) indicating a dense urban system, but this can vary.
#
# ### Insights on Urban Systems in the UK:
# #### High Variability:
#
# - The high standard deviation in both diameter and node count indicates significant variability in the size and complexity of urban systems across the UK.
# - Urban systems range from small towns with a few hundred nodes to large cities with tens of thousands of nodes.
#
# #### Compact vs. Spread-Out Systems:
#
# - The score helps in understanding how compact or spread-out an urban system is. Systems with lower scores are more compact, while higher scores indicate more spread-out systems.
# - Most urban systems have a score between 0.085 and 0.16, suggesting a mix of moderately compact and moderately spread-out systems.
#
# #### Large Urban Systems:
#
# - The maximum node count of 188,635 and the maximum diameter of 1311 likely correspond to London or other large metropolitan areas.
# - These large urban systems are characterized by extensive infrastructure and significant urban sprawl.
#
# #### Median Values:
#
# - The median node count of 429 and the median diameter of 54 suggest that a typical urban system in the UK is relatively small to medium-sized.
# - These typical systems are likely towns or small cities.
#
# #### Density and Efficiency:
#
# - The average score of 0.12209 indicates that on average, UK urban systems have a balanced ratio of diameter to node count.
# - This average score suggests that while there is some spread, the urban systems are not excessively spread out, maintaining a level of compactness.
#
# ### Insights for Urban Planning:
# #### Infrastructure Needs:
#
# - Large urban systems like London require extensive infrastructure planning to handle their complexity and size.
# - Transportation, utilities, and services must be scaled appropriately.
#
# #### Urban Sprawl Management:
#
# - The significant variability in urban systems suggests a need for tailored approaches in managing urban sprawl.
# - Policies could focus on promoting compact urban growth to improve efficiency and reduce environmental impact.
#
# #### Resource Allocation:
#
# - Smaller urban systems may need different resource allocation compared to larger ones.
# - Urban planning must consider the unique needs of different sizes and types of urban systems.
#
# By analysing and interpreting this data, urban planners and policymakers can make informed decisions to improve the efficiency, livability, and sustainability of urban systems across the UK.

# %% [markdown]
# ## E4. Plots of Standardised DF

# %%
q_low = 0.05
q_high = 0.95

score_low, score_high = sorted_clusters_df['score'].quantile([q_low, q_high])
diameter_low, diameter_high = sorted_clusters_df['diameter'].quantile([q_low, q_high])
node_count_low, node_count_high = sorted_clusters_df['node_count'].quantile([q_low, q_high])

# Filter the DataFrame to remove the top and bottom 10% of values for each column
filtered_df = sorted_clusters_df[
    (sorted_clusters_df['score'] >= score_low) & (sorted_clusters_df['score'] <= score_high) &
    (sorted_clusters_df['diameter'] >= diameter_low) & (sorted_clusters_df['diameter'] <= diameter_high) &
    (sorted_clusters_df['node_count'] >= node_count_low) & (sorted_clusters_df['node_count'] <= node_count_high)
]

# Print the descriptive statistics of the filtered data
filtered_descriptive_stats = filtered_df.describe()
print(filtered_descriptive_stats)
# Out:
#           diameter   node_count        score
# count  1196.000000  1196.000000  1196.000000
# mean     63.865385   685.573579     0.119882
# std      28.732256   610.978106     0.040211
# min      33.000000   203.000000     0.040621
# 25%      43.000000   301.000000     0.088370
# 50%      55.000000   453.000000     0.119982
# 75%      75.000000   801.250000     0.150882
# max     180.000000  3793.000000     0.205674

# %%
# Plot histogram of filtered scores
plt.figure(figsize=(10, 6))
plt.hist(filtered_df['score'], bins=20, edgecolor='black')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.title('Histogram of Filtered Cluster Scores')
plt.grid(True)
plt.show()

# Plot scatter plot of filtered diameter vs. score
plt.figure(figsize=(10, 6))
plt.scatter(filtered_df['diameter'], filtered_df['score'], alpha=0.5)
plt.xlabel('Diameter')
plt.ylabel('Score')
plt.title('Scatter Plot of Filtered Diameter vs. Score')
plt.grid(True)
plt.show()

# Plot histogram of filtered diameters
plt.figure(figsize=(10, 6))
plt.hist(filtered_df['diameter'], bins=20, edgecolor='black')
plt.xlabel('Diameter')
plt.ylabel('Frequency')
plt.title('Histogram of Filtered Cluster Diameters')
plt.grid(True)
plt.show()

# Plot scatter plot of filtered diameter vs. node_count
plt.figure(figsize=(10, 6))
plt.scatter(filtered_df['diameter'], filtered_df['node_count'], alpha=0.5)
plt.xlabel('Diameter')
plt.ylabel('Node Count')
plt.title('Scatter Plot of Filtered Diameter vs. Node Count')
plt.grid(True)
plt.show()

# Plot histogram of filtered node counts
plt.figure(figsize=(10, 6))
plt.hist(filtered_df['node_count'], bins=20, edgecolor='black')
plt.xlabel('Node Count')
plt.ylabel('Frequency')
plt.title('Histogram of Filtered Cluster Node Counts')
plt.grid(True)
plt.show()

# Plot scatter plot of filtered node_count vs. score
plt.figure(figsize=(10, 6))
plt.scatter(filtered_df['node_count'], filtered_df['score'], alpha=0.5)
plt.xlabel('Node Count')
plt.ylabel('Score')
plt.title('Scatter Plot of Filtered Node Count vs. Score')
plt.grid(True)
plt.show()
